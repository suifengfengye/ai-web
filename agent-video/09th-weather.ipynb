# %% [markdown]
# # 1. 聚合数据 - 天气查询
#
# 文档链接：https://www.juhe.cn/apiexplorer/73

# %%
import requests
import json

# 1213-根据城市查询天气 - 代码参考（根据实际业务情况修改）

# 基本参数配置
apiUrl = 'http://apis.juhe.cn/simpleWeather/query'  # 接口请求URL
apiKey = input('请输入您申请的调用APIkey：')  # 在个人中心->我的数据,接口名称上方查看

# 接口请求入参配置
requestParams = {
    'key': apiKey,
    'city': '广州',
}

# 发起接口网络请求
response = requests.get(apiUrl, params=requestParams)

# 解析响应结果
if response.status_code == 200:
    responseResult = response.json()
    # 网络请求成功。可依据业务逻辑和接口文档说明自行处理。
    print(json.dumps(responseResult, ensure_ascii=False, indent=2))
else:
    # 网络异常等因素，解析结果异常。可依据业务逻辑自行处理。
    print('请求异常')
# Out:
# {
#   "reason": "查询成功!",
#   "result": {
#     "city": "广州",
#     "realtime": {
#       "temperature": "17",
#       "humidity": "93",
#       "info": "晴",
#       "wid": "00",
#       "direct": "北风",
#       "power": "1-3级",
#       "aqi": "65"
#     },
#     "future": [
#       {
#         "date": "2026-02-04",
#         "temperature": "14/24℃",
#         "weather": "阴转多云",
#         "wid": {
#           "day": "02",
#           "night": "01"
#         },
#         "direct": "南风转微风"
#       },
#       {
#         "date": "2026-02-05",
#         "temperature": "15/25℃",
#         "weather": "多云转小雨",
#         "wid": {
#           "day": "01",
#           "night": "07"
#         },
#         "direct": "微风"
#       },
#       {
#         "date": "2026-02-06",
#         "temperature": "13/23℃",
#         "weather": "小雨",
#         "wid": {
#           "day": "07",
#           "night": "07"
#         },
#         "direct": "微风转北风"
#       },
#       {
#         "date": "2026-02-07",
# ...

# %% [markdown]
# # 2. 备选 和风天气
#
# 文档链接：https://dev.qweather.com/docs/api/weather/
