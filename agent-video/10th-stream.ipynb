# %% [markdown]
# # 1. 流式输出
#
# 文档链接：https://docs.langchain.com/oss/python/langchain/streaming/overview#accessing-completed-messages
#
# create_agent()方法设置流式传输的参数:
# - stream_mode: updates|messages|custom,3个取值
#     - updates: 在agent的每个步骤执行后，流式地传输状态更新。
#     - messages：LLM的流式输出
#     - custom：自定义传输流式数据，一般是在@tool节点内部使用了流式数据传输的方式时会使用到。
#
# ```python
# # 1. 方式1
# agent.stream()
# # 2.方式2-异步
# agent.astream()
# ```

# %% [markdown]
# 提示词：
# 目录 agent-video/10th-stream 下，我实现了一个旅游攻略的智能体，含有3个工具调用。
# 1、使用技术栈:langchain 1.0 + langgraph 1.0+
# 2、使用conda虚拟环境(agent-video)运行。
# 目前入口处调用是invoke，不是流式的，请改成流式输出的方式（要求给出stream和astream的调用代码，可以分别封装在两个方法中，方便切换）。langchain创建的智能体如何进行流式输出可以参考文档  agent-video/10th-stream.ipynb 。在控制台的格式要求：
# 1. 调用工具 xxxxx
# 请求体: xxxx
# 返回结果：xxx
# -----------------------------(分割线)
# 2. 调用工具 xxxxx2
# 请求体: xxxx2
# 返回结果：xxx2
# -----------------------------(分割线)
# ...... (更多工具调用)
# -----------------------------(分割线)
# 回答正文：（流式输出）
